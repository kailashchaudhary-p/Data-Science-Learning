# %%
import numpy as np
import pandas as pd

# %%
dec1={
    "name":['ram','rohan','kailash','kuljeet'],
    "marks":[45,65,67,78],
    "city":['kolkata','mukerian','gurdaspur','jammu']
}

# %%
df=pd.DataFrame(dec1)

# %%
df
# Out:
#       name  marks       city
# 0      ram     45    kolkata
# 1    rohan     65   mukerian
# 2  kailash     67  gurdaspur
# 3  kuljeet     78      jammu

# %%
df.to_csv('student_marks.csv',index)
