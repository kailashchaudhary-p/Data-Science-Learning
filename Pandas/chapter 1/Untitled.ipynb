# %% [markdown]
# <a href="https://colab.research.google.com/github/kailashchaudhary-p/Data-Science-Learning/blob/main/Pandas/chapter%201/Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
s=pd.Series([10,20,30,40,50])
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
s.dtype
s.index
s.values
# Out:
# array([10, 20, 30, 40, 50])

# %%
s.name='numbers'
print(s.name)
# Out:
# numbers

# %%
#indexing
s[0]
s[0:1:4]
# Out:
# 0    10
# Name: numbers, dtype: int64

# %%
s[3:0]
# Out:
# Series([], Name: numbers, dtype: int64)

# %%
#ilock--> location based index
s.iloc[3]
s.iloc[[1,3,4]]
# Out:
# 1    20
# 3    40
# 4    50
# Name: numbers, dtype: int64

# %%
#now we will change our indexing for perr=ticular usage
index=['apple','banana','grapes','orange','mango']
s.index=index

# %%
s.loc['apple']
# Out:
# np.int64(10)

# %%
s2={
    'apple':0.7,
    'banana':0.6,
    'grapes':3.0,
    'avacado':1.0,
    'mango':0.9,
    'cheeri':0.8,
    'kiwi':1.1,
    'orange':2.5,
    'blackberries':2.3
}
s2
# Out:
# {'apple': 0.7,
#  'banana': 0.6,
#  'grapes': 3.0,
#  'avacado': 1.0,
#  'mango': 0.9,
#  'cheeri': 0.8,
#  'kiwi': 1.1,
#  'orange': 2.5,
#  'blackberries': 2.3}

# %%
s2=pd.Series(s2)
s2
# Out:
# apple           0.7
# banana          0.6
# grapes          3.0
# avacado         1.0
# mango           0.9
# cheeri          0.8
# kiwi            1.1
# orange          2.5
# blackberries    2.3
# dtype: float64

# %%
print(type(s2))
# Out:
# <class 'pandas.core.series.Series'>

# %%
s2.unique()
# Out:
# array([0.7, 0.6, 3. , 1. , 0.9, 0.8, 1.1, 2.5, 2.3])

# %%
s2.count()
# Out:
# np.int64(9)

# %%
s2.describe()
# Out:
# count    9.000000
# mean     1.433333
# std      0.905539
# min      0.600000
# 25%      0.800000
# 50%      1.000000
# 75%      2.300000
# max      3.000000
# dtype: float64

# %%
#Logic oprator

# %%
#Data Frame (df)
data={
    'name':['kailash','ajay','aman','alice','bob','charlie'],
    'age':[20,25,30,35,19,22],
    'Department':['IT','HR','Finance','IT','HR','Finance'],
    'salary':[50000,60000,40000,250000,300000,80000]
}
data
# Out:
# {'name': ['kailash', 'ajay', 'aman', 'alice', 'bob', 'charlie'],
#  'age': [20, 25, 30, 35, 19, 22],
#  'Department': ['IT', 'HR', 'Finance', 'IT', 'HR', 'Finance'],
#  'salary': [50000, 60000, 40000, 250000, 300000, 80000]}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#       name  age Department  salary
# 0  kailash   20         IT   50000
# 1     ajay   25         HR   60000
# 2     aman   30    Finance   40000
# 3    alice   35         IT  250000
# 4      bob   19         HR  300000
# 5  charlie   22    Finance   80000

# %%
df.head(2)
# Out:
#       name  age Department  salary
# 0  kailash   20         IT   50000
# 1     ajay   25         HR   60000

# %%
df.tail(5)
# Out:
#       name  age Department  salary
# 1     ajay   25         HR   60000
# 2     aman   30    Finance   40000
# 3    alice   35         IT  250000
# 4      bob   19         HR  300000
# 5  charlie   22    Finance   80000

# %%
#loc&iloc in df

# %%
df.loc[1:3]
# Out:
#     name  age Department  salary
# 1   ajay   25         HR   60000
# 2   aman   30    Finance   40000
# 3  alice   35         IT  250000

# %%
df.iloc[1:3,[1,3
             ]]
# Out:
#    age  salary
# 1   25   60000
# 2   30   40000

# %%
#the direct indexing is in data frame or series is very comlex thats why we will use loc or iloc

# %%
#to se perticuler column or multiple
df.age
# Out:
# 0    20
# 1    25
# 2    30
# 3    35
# 4    19
# 5    22
# Name: age, dtype: int64

# %%
df['age']
# Out:
# 0    20
# 1    25
# 2    30
# 3    35
# 4    19
# 5    22
# Name: age, dtype: int64

# %%
df['age'].unique(

)
# Out:
# array([20, 25, 30, 35, 19, 22])

# %%
df.describe()
# Out:
#              age         salary
# count   6.000000       6.000000
# mean   25.166667  130000.000000
# std     6.242329  114192.819389
# min    19.000000   40000.000000
# 25%    20.500000   52500.000000
# 50%    23.500000   70000.000000
# 75%    28.750000  207500.000000
# max    35.000000  300000.000000

# %%
df.rename(columns={'name':'Name'},inplace=True)

# %%
df
# Out:
#       Name  age Department  salary
# 0  kailash   20         IT   50000
# 1     ajay   25         HR   60000
# 2     aman   30    Finance   40000
# 3    alice   35         IT  250000
# 4      bob   19         HR  300000
# 5  charlie   22    Finance   80000

# %%
#broadcasting in pandas
df['salary']=df['salary']+5000

# %%
df
# Out:
#       Name  age Department  salary
# 0  kailash   20         IT   55000
# 1     ajay   25         HR   65000
# 2     aman   30    Finance   45000
# 3    alice   35         IT  255000
# 4      bob   19         HR  305000
# 5  charlie   22    Finance   85000

# %%
df.drop(columns=['salary'],inplace=True)

# %%
import numpy as np
dataset={
    'name':['kailash','ajay',np.nan,'aman','alice','bob',np.nan,'charlie',np.nan],
    'urn':[789,123,456,741,np.nan,963,852,np.nan,951],
    'project':['banking app','task managment','clone spotify','card managment',np.nan,'player','xyz','abc','k']
}
df2=pd.DataFrame(dataset)

# %%
df2
# Out:
#       name    urn         project
# 0  kailash  789.0     banking app
# 1     ajay  123.0  task managment
# 2      NaN  456.0   clone spotify
# 3     aman  741.0  card managment
# 4    alice    NaN             NaN
# 5      bob  963.0          player
# 6      NaN  852.0             xyz
# 7  charlie    NaN             abc
# 8      NaN  951.0               k

# %%
#now this is our prectice set in this we work on df2 data opration and we clean the data
df2.isnull().sum()
# Out:
# name       3
# urn        2
# project    1
# dtype: int64

# %%
df2.dropna()
# Out:
#       name    urn         project
# 0  kailash  789.0     banking app
# 1     ajay  123.0  task managment
# 3     aman  741.0  card managment
# 5      bob  963.0          player

# %%
df2.dropna(how='all')
# Out:
#       name    urn         project
# 0  kailash  789.0     banking app
# 1     ajay  123.0  task managment
# 2      NaN  456.0   clone spotify
# 3     aman  741.0  card managment
# 4    alice    NaN             NaN
# 5      bob  963.0          player
# 6      NaN  852.0             xyz
# 7  charlie    NaN             abc
# 8      NaN  951.0               k

# %%
df2.dropna(how='any')
# Out:
#       name    urn         project
# 0  kailash  789.0     banking app
# 1     ajay  123.0  task managment
# 3     aman  741.0  card managment
# 5      bob  963.0          player

# %%
#this the other way fill the null values
df2.fillna(5)
# Out:
#       name    urn         project
# 0  kailash  789.0     banking app
# 1     ajay  123.0  task managment
# 2        5  456.0   clone spotify
# 3     aman  741.0  card managment
# 4    alice    5.0               5
# 5      bob  963.0          player
# 6        5  852.0             xyz
# 7  charlie    5.0             abc
# 8        5  951.0               k

# %%
df
# Out:
#       Name  age Department
# 0  kailash   20         IT
# 1     ajay   25         HR
# 2     aman   30    Finance
# 3    alice   35         IT
# 4      bob   19         HR
# 5  charlie   22    Finance

# %%
df2
# Out:
#       name    urn         project
# 0  kailash  789.0     banking app
# 1     ajay  123.0  task managment
# 2      NaN  456.0   clone spotify
# 3     aman  741.0  card managment
# 4    alice    NaN             NaN
# 5      bob  963.0          player
# 6      NaN  852.0             xyz
# 7  charlie    NaN             abc
# 8      NaN  951.0               k

# %%
df2['urn'].fillna(df2['urn'].median())
# Out:
# 0    789.0
# 1    123.0
# 2    456.0
# 3    741.0
# 4    789.0
# 5    963.0
# 6    852.0
# 7    789.0
# 8    951.0
# Name: urn, dtype: float64

# %%
#now we will know about the forward fill & backword fill
#the forword fill is top to bottum & the backword fill is bottom to top
df2['urn'].fillna(method='ffill')
# Out:
# /tmp/ipykernel_3043/880483959.py:3: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df2['urn'].fillna(method='ffill')
# 0    789.0
# 1    123.0
# 2    456.0
# 3    741.0
# 4    741.0
# 5    963.0
# 6    852.0
# 7    852.0
# 8    951.0
# Name: urn, dtype: float64

# %%
df2['urn'].fillna(method='bfill')
# Out:
# /tmp/ipykernel_3043/489831362.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df2['urn'].fillna(method='bfill')
# 0    789.0
# 1    123.0
# 2    456.0
# 3    741.0
# 4    963.0
# 5    963.0
# 6    852.0
# 7    951.0
# 8    951.0
# Name: urn, dtype: float64

# %%
#now we will replace the value
df2['name']=df2['name'].replace('kailash','harsh')
df2
# Out:
#       name    urn         project
# 0    harsh  789.0     banking app
# 1     ajay  123.0  task managment
# 2      NaN  456.0   clone spotify
# 3     aman  741.0  card managment
# 4    alice    NaN             NaN
# 5      bob  963.0          player
# 6      NaN  852.0             xyz
# 7  charlie    NaN             abc
# 8      NaN  951.0               k

# %%
df2
# Out:
#       name    urn         project
# 0    harsh  789.0     banking app
# 1     ajay  123.0  task managment
# 2      NaN  456.0   clone spotify
# 3     aman  741.0  card managment
# 4    alice    NaN             NaN
# 5      bob  963.0          player
# 6      NaN  852.0             xyz
# 7  charlie    NaN             abc
# 8      NaN  951.0               k

# %%
#now we will deal with duplicate values
df_dup=df2.duplicated()
df_dup
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# dtype: bool

# %%
#now we will learn about the lamda function in pandasdf
df2['name_upper'] = df2['name'].apply(lambda x: x.upper() if pd.notna(x) else x)
df2
# Out:
#       name    urn         project name_upper
# 0    harsh  789.0     banking app      HARSH
# 1     ajay  123.0  task managment       AJAY
# 2      NaN  456.0   clone spotify        NaN
# 3     aman  741.0  card managment       AMAN
# 4    alice    NaN             NaN      ALICE
# 5      bob  963.0          player        BOB
# 6      NaN  852.0             xyz        NaN
# 7  charlie    NaN             abc    CHARLIE
# 8      NaN  951.0               k        NaN

# %%
#join & mearg
Department_info={
    'department_id':[1,2,3,4],
    'department_name':['IT','HR','Finance','Marketing'],
}
df3=pd.DataFrame(Department_info)
df3
# Out:
#    department_id department_name
# 0              1              IT
# 1              2              HR
# 2              3         Finance
# 3              4       Marketing

# %%
#concat data frame
pd.concat([df2,df3,df])
# Out:
#       name    urn         project name_upper  department_id department_name  \
# 0    harsh  789.0     banking app      HARSH            NaN             NaN
# 1     ajay  123.0  task managment       AJAY            NaN             NaN
# 2      NaN  456.0   clone spotify        NaN            NaN             NaN
# 3     aman  741.0  card managment       AMAN            NaN             NaN
# 4    alice    NaN             NaN      ALICE            NaN             NaN
# 5      bob  963.0          player        BOB            NaN             NaN
# 6      NaN  852.0             xyz        NaN            NaN             NaN
# 7  charlie    NaN             abc    CHARLIE            NaN             NaN
# 8      NaN  951.0               k        NaN            NaN             NaN
# 0      NaN    NaN             NaN        NaN            1.0              IT
# 1      NaN    NaN             NaN        NaN            2.0              HR
# ...

# %%
pd.concat([df2,df3,df],axis=1)
# Out:
#       name    urn         project name_upper  department_id department_name  \
# 0    harsh  789.0     banking app      HARSH            1.0              IT
# 1     ajay  123.0  task managment       AJAY            2.0              HR
# 2      NaN  456.0   clone spotify        NaN            3.0         Finance
# 3     aman  741.0  card managment       AMAN            4.0       Marketing
# 4    alice    NaN             NaN      ALICE            NaN             NaN
# 5      bob  963.0          player        BOB            NaN             NaN
# 6      NaN  852.0             xyz        NaN            NaN             NaN
# 7  charlie    NaN             abc    CHARLIE            NaN             NaN
# 8      NaN  951.0               k        NaN            NaN             NaN
#
#       Name   age Department
# 0  kailash  20.0         IT
# 1     ajay  25.0         HR
# 2     aman  30.0    Finance
# 3    alice  35.0         IT
# 4      bob  19.0         HR
# 5  charlie  22.0    Finance
# ...

# %%
#now the next step is work on real data and we will cleaning tahe data the null values & invalid values
data = pd.read_csv('/content/customers-1000.csv')
data
# Out:
#      Index      Customer Id First Name Last Name                      Company  \
# 0        1  dE014d010c7ab0c     Andrew   Goodman                Stewart-Flynn
# 1        2  2B54172c8b65eC3      Alvin      Lane  Terry, Proctor and Lawrence
# 2        3  d794Dd48988d2ac      Jenna   Harding                 Bailey Group
# 3        4  3b3Aa4aCc68f3Be   Fernando      Ford                 Moss-Maxwell
# 4        5  D60df62ad2ae41E       Kara     Woods              Mccarthy-Kelley
# ..     ...              ...        ...       ...                          ...
# 995    996  FbcCaF483aFaFAE      Diana    Monroe                  Bass-Wilson
# 996    997  979c4D58Ae9a9cc      Jerry   Morales                   Pratt-King
# 997    998  D0DcF6a4BcefCc8     Tracie     Floyd     Holt, Wilson and Shields
# 998    999  90EE9CbbDa374E9       Paul    Barnes     Brown, Oliver and Haynes
# 999   1000  51732B5b2328015    Dominic     Duran                   Durham LLC
#
# ...

# %%
data .info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Index              1000 non-null   int64
#  1   Customer Id        1000 non-null   object
#  2   First Name         1000 non-null   object
#  3   Last Name          1000 non-null   object
#  4   Company            1000 non-null   object
#  5   City               1000 non-null   object
#  6   Country            1000 non-null   object
#  7   Phone 1            1000 non-null   object
#  8   Phone 2            1000 non-null   object
#  9   Email              1000 non-null   object
#  10  Subscription Date  1000 non-null   object
#  11  Website            1000 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 93.9+ KB
