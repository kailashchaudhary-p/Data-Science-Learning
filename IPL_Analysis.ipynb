# %% [markdown]
# <a href="https://colab.research.google.com/github/kailashchaudhary-p/Data-Science-Learning/blob/main/IPL_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
''' Project ka main goal kya hai?

Indian Premier League (IPL) ke historical data ko analyze karke yeh samajhna:

Kaun best players hain
Kaunsi teams consistent hain
Match jeetne ke patterns kya hain

Matlab: data se story nikalna'''
# Out:
# ' Project ka main goal kya hai?\n\nIndian Premier League (IPL) ke historical data ko analyze karke yeh samajhna:\n\nKaun best players hain\nKaunsi teams consistent hain\nMatch jeetne ke patterns kya hain\n\nMatlab: data se story nikalna'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plot
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
matches=pd.read_csv('/content/drive/MyDrive/IPL/matches.csv')
delivers=pd.read_csv('/content/drive/MyDrive/IPL/delivers.csv')

# %%
matches.head()
# Out:
#    id  season       city      date                        team1  \
# 0   1    2017  Hyderabad  5/4/2017          Sunrisers Hyderabad
# 1   2    2017       Pune  6/4/2017               Mumbai Indians
# 2   3    2017     Rajkot  7/4/2017                Gujarat Lions
# 3   4    2017     Indore  8/4/2017       Rising Pune Supergiant
# 4   5    2017  Bangalore  8/4/2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# 0  normal           0          Sunrisers Hyderabad           35
# 1  normal           0       Rising Pune Supergiant            0
# 2  normal           0        Kolkata Knight Riders            0
# 3  normal           0              Kings XI Punjab            0
# 4  normal           0  Royal Challengers Bangalore           15
#
#    win_by_wickets player_of_match                                      venue  \
# 0               0    Yuvraj Singh  Rajiv Gandhi International Stadium, Uppal
# 1               7       SPD Smith    Maharashtra Cricket Association Stadium
# 2              10         CA Lynn     Saurashtra Cricket Association Stadium
# 3               6      GJ Maxwell                     Holkar Cricket Stadium
# 4               0       KM Jadhav                      M Chinnaswamy Stadium
#
#           umpire1        umpire2  umpire3
# 0     AY Dandekar       NJ Llong      NaN
# 1  A Nand Kishore         S Ravi      NaN
# 2     Nitin Menon      CK Nandan      NaN
# 3    AK Chaudhary  C Shamshuddin      NaN
# 4             NaN            NaN      NaN

# %%
delivers.head()
# Out:
#        ID  Innings  Overs  BallNumber      Batter   Bowler  NonStriker  \
# 0  981001        1      0           1  RV Uthappa  P Kumar   G Gambhir
# 1  981001        1      0           2  RV Uthappa  P Kumar   G Gambhir
# 2  981001        1      0           3   G Gambhir  P Kumar  RV Uthappa
# 3  981001        1      0           4   G Gambhir  P Kumar  RV Uthappa
# 4  981001        1      0           5  RV Uthappa  P Kumar   G Gambhir
#
#   ExtraType  BatsmanRun  ExtrasRun  TotalRun  IsWicketDelivery PlayerOut Kind  \
# 0       NaN           0          0         0                 0       NaN  NaN
# 1       NaN           1          0         1                 0       NaN  NaN
# 2       NaN           0          0         0                 0       NaN  NaN
# 3       NaN           1          0         1                 0       NaN  NaN
# 4       NaN           1          0         1                 0       NaN  NaN
#
#   FieldersInvolved            BattingTeam
# 0              NaN  Kolkata Knight Riders
# 1              NaN  Kolkata Knight Riders
# 2              NaN  Kolkata Knight Riders
# 3              NaN  Kolkata Knight Riders
# 4              NaN  Kolkata Knight Riders

# %%
matches.notnull().sum()
# Out:
# id                 636
# season             636
# city               629
# date               636
# team1              636
# team2              636
# toss_winner        636
# toss_decision      636
# result             636
# dl_applied         636
# winner             633
# win_by_runs        636
# win_by_wickets     636
# player_of_match    633
# venue              636
# umpire1            635
# umpire2            635
# umpire3              0
# dtype: int64

# %%
matches=matches.dropna()

# %%
top_batsman = delivers.groupby('Batter')['BatsmanRun'].sum().sort_values(ascending=False).head(10)

print(top_batsman)
# Out:
# Batter
# V Kohli           9050
# RG Sharma         7291
# S Dhawan          6769
# DA Warner         6567
# KL Rahul          5712
# SK Raina          5536
# MS Dhoni          5439
# AM Rahane         5250
# AB de Villiers    5181
# SV Samson         5134
# Name: BatsmanRun, dtype: int64

# %%
top_batsman.plot(kind='bar',figsize=(10,6))
plot.title('Top Batsman')
plot.xlabel('Batsman')
plot.ylabel('Total Runs')
plot.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
