# %% [markdown]
# <a href="https://colab.research.google.com/github/kailashchaudhary-p/Data-Science-Learning/blob/main/IPL_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
''' Project ka main goal kya hai?

Indian Premier League (IPL) ke historical data ko analyze karke yeh samajhna:

Kaun best players hain
Kaunsi teams consistent hain
Match jeetne ke patterns kya hain

Matlab: data se story nikalna'''
# Out:
# ' Project ka main goal kya hai?\n\nIndian Premier League (IPL) ke historical data ko analyze karke yeh samajhna:\n\nKaun best players hain\nKaunsi teams consistent hain\nMatch jeetne ke patterns kya hain\n\nMatlab: data se story nikalna'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploaded = files.upload()
matches = pd.read_csv("matches.csv")
deliveries = pd.read_csv("ipl_2022_deliveries (1).csv")
deliveries2= pd.read_csv("ipl_2023_deliveries.csv")
deliveries3= pd.read_csv("ipl_2023_deliveries.csv")
deliveries4= pd.read_csv("ipl_2024_deliveries.csv")
deliveries5= pd.read_csv("ipl_2025_deliveries.csv")
deliveries6= pd.read_csv("ipl_2026_deliveries.csv")
# Out:
#      <input type="file" id="files-9f6efe2f-3136-42bc-a223-d14b5be75554" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9f6efe2f-3136-42bc-a223-d14b5be75554">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
matches.head()
# Out:
#    id  season       city      date                        team1  \
# 0   1    2017  Hyderabad  5/4/2017          Sunrisers Hyderabad
# 1   2    2017       Pune  6/4/2017               Mumbai Indians
# 2   3    2017     Rajkot  7/4/2017                Gujarat Lions
# 3   4    2017     Indore  8/4/2017       Rising Pune Supergiant
# 4   5    2017  Bangalore  8/4/2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# 0  normal           0          Sunrisers Hyderabad           35
# ...

# %%
matches.isnull().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               3
# win_by_runs          0
# win_by_wickets       0
# player_of_match      3
# venue                0
# umpire1              1
# umpire2              1
# umpire3            636
# dtype: int64

# %%
deliveries.head()
# Out:
#    match_id  season  match_no          date                     venue  \
# 0    202201    2022         1  Mar 26, 2022  Wankhede Stadium, Mumbai
# 1    202201    2022         1  Mar 26, 2022  Wankhede Stadium, Mumbai
# 2    202201    2022         1  Mar 26, 2022  Wankhede Stadium, Mumbai
# 3    202201    2022         1  Mar 26, 2022  Wankhede Stadium, Mumbai
# 4    202201    2022         1  Mar 26, 2022  Wankhede Stadium, Mumbai
#
#   batting_team bowling_team  innings  over  striker       bowler  runs_of_bat  \
# 0          CSK          KKR        1   0.1  Gaikwad  Umesh Yadav            0
# 1          CSK          KKR        1   0.1  Gaikwad  Umesh Yadav            0
# 2          CSK          KKR        1   0.2  Gaikwad  Umesh Yadav            0
# 3          CSK          KKR        1   0.2  Gaikwad  Umesh Yadav            0
# 4          CSK          KKR        1   0.3  Gaikwad  Umesh Yadav            0
#
#    extras  wide  legbyes  byes  noballs wicket_type player_dismissed  \
# ...

# %%
matches = matches.dropna()

# %%
top_batsman = deliveries.groupby('batsman')['batsman_runs'].sum().sort_values(ascending=False).head(10)

print(top_batsman)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1440/4011314259.py in <cell line: 0>()
# ----> 1 top_batsman = deliveries.groupby('batsman')['batsman_runs'].sum().sort_values(ascending=False).head(10)
#       2
#       3 print(top_batsman)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9181             raise TypeError("You have to supply one of 'by' and 'level'")
#    9182
# -> 9183         return DataFrameGroupBy(
#    9184             obj=self,
#    9185             keys=by,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1327
#    1328         if grouper is None:
# ...
