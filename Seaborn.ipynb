# %% [markdown]
# <a href="https://colab.research.google.com/github/kailashchaudhary-p/Data-Science-Learning/blob/main/Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# Example dataset
tips = sns.load_dataset("tips")
# Create a scatter plot with regression line
sns.lmplot(data=tips, x="total_bill", y="tip", hue="sex", height=5, aspect=1.2)
plt.title("Total Bill vs Tip by Gender")
plt.show()

# %%
import seaborn as sns
import pandas as pd
import numpy as np

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
taxis=sns.load_dataset('taxis')

# %%
taxis.head()
# Out:
#                pickup             dropoff  passengers  distance  fare   tip  \
# 0 2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1 2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2 2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3 2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4 2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0  1.10
#
#    tolls  total   color      payment            pickup_zone  \
# 0    0.0  12.95  yellow  credit card        Lenox Hill West
# 1    0.0   9.30  yellow         cash  Upper West Side South
# 2    0.0  14.16  yellow  credit card          Alphabet City
# 3    0.0  36.95  yellow  credit card              Hudson Sq
# 4    0.0  13.40  yellow  credit card           Midtown East
#
#             dropoff_zone pickup_borough dropoff_borough
# 0    UN/Turtle Bay South      Manhattan       Manhattan
# ...

# %%
taxis['pickup'].value_counts()
# Out:
# pickup
# 2019-03-13 10:57:06    2
# 2019-03-28 08:21:02    2
# 2019-03-19 14:40:14    2
# 2019-03-28 10:05:08    2
# 2019-03-15 08:39:34    2
#                       ..
# 2019-03-05 17:42:07    1
# 2019-03-13 13:28:34    1
# 2019-03-08 13:27:32    1
# 2019-03-27 02:40:06    1
# 2019-03-24 10:36:40    1
# Name: count, Length: 6414, dtype: int64

# %%
taxis['dropoff_zone'].value_counts()
# Out:
# dropoff_zone
# Upper East Side North    245
# Murray Hill              220
# Midtown Center           215
# Upper East Side South    177
# Midtown East             176
#                         ...
# Queensboro Hill            1
# Homecrest                  1
# Madison                    1
# Morrisania/Melrose         1
# Brooklyn Navy Yard         1
# Name: count, Length: 203, dtype: int64

# %%
sns.scatterplot(data=taxis,x='pickup_zone',y='dropoff_zone')
# Out:
# <Axes: xlabel='pickup_zone', ylabel='dropoff_zone'>

# %%
sns.histplot(data=taxis,x='pickup_zone',y='dropoff_zone')
# Out:
# <Axes: xlabel='pickup_zone', ylabel='dropoff_zone'>

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
titanic=sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic['who'].value_counts()
# Out:
# who
# man      537
# woman    271
# child     83
# Name: count, dtype: int64

# %%
titanic['embark_town'].value_counts()
# Out:
# embark_town
# Southampton    644
# Cherbourg      168
# Queenstown      77
# Name: count, dtype: int64

# %%
sns.scatterplot(data=titanic,x='who',y='embark_town')
# Out:
# <Axes: xlabel='who', ylabel='embark_town'>

# %%
sns.histplot(data=titanic,x='who',y='embark_town')
plt.title('This is the data of titanic accident')
# Out:
# Text(0.5, 1.0, 'This is the data of titanic accident')

# %%
penguins=sns.load_dataset('penguins')
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
penguins['species'].value_counts()
# Out:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %%
penguins['island'].value_counts()
# Out:
# island
# Biscoe       168
# Dream        124
# Torgersen     52
# Name: count, dtype: int64

# %%
penguins['bill_depth_mm'].value_counts()
# Out:
# bill_depth_mm
# 17.0    12
# 17.9    10
# 18.6    10
# 18.5    10
# 15.0    10
#         ..
# 13.2     1
# 13.6     1
# 13.1     1
# 13.3     1
# 14.9     1
# Name: count, Length: 80, dtype: int64

# %%
sns.set_style('white')
sns.set_context('talk')
sns.scatterplot(data=penguins,x='species',y='island')
# Out:
# <Axes: xlabel='species', ylabel='island'>

# %%
sns.set_style('ticks')
sns.scatterplot(data=penguins,y='bill_depth_mm',x='island',hue='bill_length_mm',style='sex',alpha=1)
# Out:
# <Axes: xlabel='island', ylabel='bill_depth_mm'>

# %%
sns.stripplot(data=penguins,x='species',y='bill_length_mm',hue='sex',dodge=True,jitter=True)
# Out:
# <Axes: xlabel='species', ylabel='bill_length_mm'>

# %%
mpg=sns.load_dataset('mpg')
mpg
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
mpg['name'].value_counts()
# Out:
# name
# ford pinto             6
# ford maverick          5
# amc matador            5
# toyota corolla         5
# amc hornet             4
#                       ..
# amc concord dl         1
# volkswagen rabbit l    1
# mazda glc custom l     1
# mazda glc custom       1
# chevy s-10             1
# Name: count, Length: 305, dtype: int64

# %%
mpg['acceleration'].value_counts()
mpg['horsepower'].value_counts()
# Out:
# horsepower
# 150.0    22
# 90.0     20
# 88.0     19
# 110.0    18
# 100.0    17
#          ..
# 77.0      1
# 132.0     1
# 64.0      1
# 116.0     1
# 82.0      1
# Name: count, Length: 93, dtype: int64

# %%
sns.stripplot(data=mpg,x='name',y='acceleration',hue='horsepower',dodge=True,jitter=True)
# Out:
# <Axes: xlabel='name', ylabel='acceleration'>
# /usr/local/lib/python3.12/dist-packages/IPython/core/events.py:89: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
iris=load_dataset('iris')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_6694/4141157448.py in <cell line: 0>()
# ----> 1 iris=load_dataset('iris')
#
# NameError: name 'load_dataset' is not defined
